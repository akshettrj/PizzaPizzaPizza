# %%
import itertools
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import pymc3 as pm
import scipy
import scipy.stats as stats
import seaborn.apionly as sns

from IPython.display import Image
from sklearn import preprocessing
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/apionly.py:9: UserWarning: As seaborn no longer sets a default style on import, the seaborn.apionly module is deprecated. It will be removed in a future version.
#   warnings.warn(msg, UserWarning)

# %%
# %matplotlib inline
plt.style.use('bmh')
colors = ['#348ABD', '#A60628', '#7A68A6', '#467821', '#D55E00', 
          '#CC79A7', '#56B4E9', '#009E73', '#F0E442', '#0072B2']

messages = pd.read_csv('../data/hangout_chat_data.csv')

# %%
messages
# Out:
#                 conversation_id                event_id  ... year_month is_weekend
# 0    Ugw5Xrm3ZO5mzAfKB7V4AaABAQ  7-H0Z7-FkyB7-HDBYj4KKh  ...    2014-08          0
# 1    UgwLUkm5oqPrUyjqFlR4AaABAQ  85SWvmXIEV285Sb1E65xL0  ...    2015-10          1
# 2    UgwUBKMcZgFowQTz1Rt4AaABAQ  7-H0Z7-HQQg7-H1JJEmE5K  ...    2013-12          0
# 3    UgwUBKMcZgFowQTz1Rt4AaABAQ  7-H0Z7-HQQg7-H1NQV6lMv  ...    2013-12          0
# 4    UgwUBKMcZgFowQTz1Rt4AaABAQ  7-H0Z7-HQQg7-H1RPd1OTh  ...    2013-12          0
# ..                          ...                     ...  ...        ...        ...
# 333  UgzTRpFAWz1jMcCIUIh4AaABAQ  8CLGyKiUGx58CmVkdEKRxk  ...    2016-04          1
# 334  UgzZBTqi5VMkzkwQnAh4AaABAQ  7-H0Z7-RK8A7-H0aE1onZL  ...    2015-03          0
# 335  UgzZBTqi5VMkzkwQnAh4AaABAQ  7-H0Z7-RK8A7-H0fOLn9ZE  ...    2015-03          0
# 336  UgzZBTqi5VMkzkwQnAh4AaABAQ  7-H0Z7-RK8A7-H0p9oTHDH  ...    2015-03          0
# 337  Ugzd2qvqMa_Uvw-kxpp4AaABAQ  7-H0Z7-Kt-j7-H0c1HnowU  ...    2013-09          0
#
# [338 rows x 14 columns]

# %%
ax = messages.groupby('prev_sender')['conversation_id'].size().plot(
    kind='bar', figsize=(12,3), title='Number of messages sent per recipient', color=colors[0])
ax.set_xlabel('Previous Sender')
ax.set_ylabel('Number of messages')
plt.xticks(rotation=45)

# %% [markdown]
# **DATA CLEANING**

# %%
indiv_traces = {}

# Convert categorical variables to int
le = preprocessing.LabelEncoder()
participants_idx = le.fit_transform(messages['prev_sender'])
participants = le.classes_
n_participants = len(participants)

for p in participants:
    with pm.Model() as model:
        alpha = pm.Uniform('alpha', lower=0, upper=100)
        mu = pm.Uniform('mu', lower=0, upper=100)
        
        data = messages[messages['prev_sender']==p]['time_delay_seconds'].values
        y_est = pm.NegativeBinomial('y_est', mu=mu, alpha=alpha, observed=data)

        y_pred = pm.NegativeBinomial('y_pred', mu=mu, alpha=alpha)
        
        start = pm.find_MAP()
        step = pm.Metropolis()
        trace = pm.sample(20000, step, start=start, progressbar=True)
        
        indiv_traces[p] = trace
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='15' class='' max='15' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [15/15 00:00<00:00 logp = -81.17, ||grad|| = 1.0932]
#     </div>
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:21: FutureWarning: In v4.0, pm.sample will return an `arviz.InferenceData` object instead of a `MultiTrace` by default. You can pass return_inferencedata=True or return_inferencedata=False to be safe and silence this warning.
# Sequential sampling (2 chains in 1 job)
# CompoundStep
# >Metropolis: [y_pred]
# >Metropolis: [mu]
# >Metropolis: [alpha]
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='21000' class='' max='21000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [21000/21000 00:11<00:00 Sampling chain 0, 0 divergences]
#     </div>
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='21000' class='' max='21000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [21000/21000 00:11<00:00 Sampling chain 1, 0 divergences]
#     </div>
# Sampling 2 chains for 1_000 tune and 20_000 draw iterations (2_000 + 40_000 draws total) took 24 seconds.
# The estimated number of effective samples is smaller than 200 for some parameters.
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='14' class='' max='14' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [14/14 00:00<00:00 logp = -21.485, ||grad|| = 0.018496]
#     </div>
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:21: FutureWarning: In v4.0, pm.sample will return an `arviz.InferenceData` object instead of a `MultiTrace` by default. You can pass return_inferencedata=True or return_inferencedata=False to be safe and silence this warning.
# Sequential sampling (2 chains in 1 job)
# CompoundStep
# >Metropolis: [y_pred]
# >Metropolis: [mu]
# >Metropolis: [alpha]
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='21000' class='' max='21000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [21000/21000 00:11<00:00 Sampling chain 0, 0 divergences]
#     </div>
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='21000' class='' max='21000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [21000/21000 00:11<00:00 Sampling chain 1, 0 divergences]
#     </div>
# Sampling 2 chains for 1_000 tune and 20_000 draw iterations (2_000 + 40_000 draws total) took 23 seconds.
# The number of effective samples is smaller than 10% for some parameters.
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='18' class='' max='18' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [18/18 00:00<00:00 logp = -43.369, ||grad|| = 2.6246]
#     </div>
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:21: FutureWarning: In v4.0, pm.sample will return an `arviz.InferenceData` object instead of a `MultiTrace` by default. You can pass return_inferencedata=True or return_inferencedata=False to be safe and silence this warning.
# Sequential sampling (2 chains in 1 job)
# CompoundStep
# >Metropolis: [y_pred]
# >Metropolis: [mu]
# >Metropolis: [alpha]
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='21000' class='' max='21000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [21000/21000 00:11<00:00 Sampling chain 0, 0 divergences]
#     </div>
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='21000' class='' max='21000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [21000/21000 00:11<00:00 Sampling chain 1, 0 divergences]
#     </div>
# Sampling 2 chains for 1_000 tune and 20_000 draw iterations (2_000 + 40_000 draws total) took 23 seconds.
# The rhat statistic is larger than 1.05 for some parameters. This indicates slight problems during sampling.
# The estimated number of effective samples is smaller than 200 for some parameters.
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='17' class='' max='17' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [17/17 00:00<00:00 logp = -195.94, ||grad|| = 6.2634]
#     </div>
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:21: FutureWarning: In v4.0, pm.sample will return an `arviz.InferenceData` object instead of a `MultiTrace` by default. You can pass return_inferencedata=True or return_inferencedata=False to be safe and silence this warning.
# Sequential sampling (2 chains in 1 job)
# CompoundStep
# >Metropolis: [y_pred]
# >Metropolis: [mu]
# >Metropolis: [alpha]
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='21000' class='' max='21000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [21000/21000 00:11<00:00 Sampling chain 0, 0 divergences]
#     </div>
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='21000' class='' max='21000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [21000/21000 00:11<00:00 Sampling chain 1, 0 divergences]
#     </div>
# Sampling 2 chains for 1_000 tune and 20_000 draw iterations (2_000 + 40_000 draws total) took 24 seconds.
# The estimated number of effective samples is smaller than 200 for some parameters.
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='17' class='' max='17' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [17/17 00:00<00:00 logp = -25.192, ||grad|| = 0.68771]
#     </div>
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:21: FutureWarning: In v4.0, pm.sample will return an `arviz.InferenceData` object instead of a `MultiTrace` by default. You can pass return_inferencedata=True or return_inferencedata=False to be safe and silence this warning.
# Sequential sampling (2 chains in 1 job)
# CompoundStep
# >Metropolis: [y_pred]
# >Metropolis: [mu]
# >Metropolis: [alpha]
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='21000' class='' max='21000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [21000/21000 00:11<00:00 Sampling chain 0, 0 divergences]
#     </div>
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='21000' class='' max='21000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [21000/21000 00:11<00:00 Sampling chain 1, 0 divergences]
#     </div>
# Sampling 2 chains for 1_000 tune and 20_000 draw iterations (2_000 + 40_000 draws total) took 24 seconds.
# The number of effective samples is smaller than 10% for some parameters.
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='15' class='' max='15' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [15/15 00:00<00:00 logp = -29.472, ||grad|| = 0.20681]
#     </div>
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:21: FutureWarning: In v4.0, pm.sample will return an `arviz.InferenceData` object instead of a `MultiTrace` by default. You can pass return_inferencedata=True or return_inferencedata=False to be safe and silence this warning.
# Sequential sampling (2 chains in 1 job)
# CompoundStep
# >Metropolis: [y_pred]
# >Metropolis: [mu]
# >Metropolis: [alpha]
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='21000' class='' max='21000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [21000/21000 00:11<00:00 Sampling chain 0, 0 divergences]
#     </div>
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='21000' class='' max='21000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [21000/21000 00:11<00:00 Sampling chain 1, 0 divergences]
#     </div>
# Sampling 2 chains for 1_000 tune and 20_000 draw iterations (2_000 + 40_000 draws total) took 23 seconds.
# The number of effective samples is smaller than 10% for some parameters.
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='16' class='' max='16' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [16/16 00:00<00:00 logp = -46.316, ||grad|| = 0.89041]
#     </div>
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:21: FutureWarning: In v4.0, pm.sample will return an `arviz.InferenceData` object instead of a `MultiTrace` by default. You can pass return_inferencedata=True or return_inferencedata=False to be safe and silence this warning.
# Sequential sampling (2 chains in 1 job)
# CompoundStep
# >Metropolis: [y_pred]
# >Metropolis: [mu]
# >Metropolis: [alpha]
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='21000' class='' max='21000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [21000/21000 00:11<00:00 Sampling chain 0, 0 divergences]
#     </div>
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='21000' class='' max='21000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [21000/21000 00:11<00:00 Sampling chain 1, 0 divergences]
#     </div>
# Sampling 2 chains for 1_000 tune and 20_000 draw iterations (2_000 + 40_000 draws total) took 24 seconds.
# The estimated number of effective samples is smaller than 200 for some parameters.
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='16' class='' max='16' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [16/16 00:00<00:00 logp = -71.71, ||grad|| = 1.7701]
#     </div>
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:21: FutureWarning: In v4.0, pm.sample will return an `arviz.InferenceData` object instead of a `MultiTrace` by default. You can pass return_inferencedata=True or return_inferencedata=False to be safe and silence this warning.
# Sequential sampling (2 chains in 1 job)
# CompoundStep
# >Metropolis: [y_pred]
# >Metropolis: [mu]
# >Metropolis: [alpha]
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='21000' class='' max='21000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [21000/21000 00:11<00:00 Sampling chain 0, 0 divergences]
#     </div>
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='21000' class='' max='21000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [21000/21000 00:11<00:00 Sampling chain 1, 0 divergences]
#     </div>
# Sampling 2 chains for 1_000 tune and 20_000 draw iterations (2_000 + 40_000 draws total) took 24 seconds.
# The rhat statistic is larger than 1.05 for some parameters. This indicates slight problems during sampling.
# The estimated number of effective samples is smaller than 200 for some parameters.
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='16' class='' max='16' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [16/16 00:00<00:00 logp = -49.282, ||grad|| = 1.3907]
#     </div>
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:21: FutureWarning: In v4.0, pm.sample will return an `arviz.InferenceData` object instead of a `MultiTrace` by default. You can pass return_inferencedata=True or return_inferencedata=False to be safe and silence this warning.
# Sequential sampling (2 chains in 1 job)
# CompoundStep
# >Metropolis: [y_pred]
# >Metropolis: [mu]
# >Metropolis: [alpha]
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='21000' class='' max='21000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [21000/21000 00:11<00:00 Sampling chain 0, 0 divergences]
#     </div>
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='21000' class='' max='21000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [21000/21000 00:11<00:00 Sampling chain 1, 0 divergences]
#     </div>
# Sampling 2 chains for 1_000 tune and 20_000 draw iterations (2_000 + 40_000 draws total) took 23 seconds.
# The estimated number of effective samples is smaller than 200 for some parameters.
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='17' class='' max='17' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [17/17 00:00<00:00 logp = -80.162, ||grad|| = 12.376]
#     </div>
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:21: FutureWarning: In v4.0, pm.sample will return an `arviz.InferenceData` object instead of a `MultiTrace` by default. You can pass return_inferencedata=True or return_inferencedata=False to be safe and silence this warning.
# Sequential sampling (2 chains in 1 job)
# CompoundStep
# >Metropolis: [y_pred]
# >Metropolis: [mu]
# >Metropolis: [alpha]
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='21000' class='' max='21000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [21000/21000 00:11<00:00 Sampling chain 0, 0 divergences]
#     </div>
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='21000' class='' max='21000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [21000/21000 00:11<00:00 Sampling chain 1, 0 divergences]
#     </div>
# Sampling 2 chains for 1_000 tune and 20_000 draw iterations (2_000 + 40_000 draws total) took 23 seconds.
# The rhat statistic is larger than 1.05 for some parameters. This indicates slight problems during sampling.
# The estimated number of effective samples is smaller than 200 for some parameters.
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='17' class='' max='17' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [17/17 00:00<00:00 logp = -111.36, ||grad|| = 9.9188]
#     </div>
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:21: FutureWarning: In v4.0, pm.sample will return an `arviz.InferenceData` object instead of a `MultiTrace` by default. You can pass return_inferencedata=True or return_inferencedata=False to be safe and silence this warning.
# Sequential sampling (2 chains in 1 job)
# CompoundStep
# >Metropolis: [y_pred]
# >Metropolis: [mu]
# >Metropolis: [alpha]
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='21000' class='' max='21000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [21000/21000 00:11<00:00 Sampling chain 0, 0 divergences]
#     </div>
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='21000' class='' max='21000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [21000/21000 00:11<00:00 Sampling chain 1, 0 divergences]
#     </div>
# Sampling 2 chains for 1_000 tune and 20_000 draw iterations (2_000 + 40_000 draws total) took 24 seconds.
# The estimated number of effective samples is smaller than 200 for some parameters.
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='18' class='' max='18' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [18/18 00:00<00:00 logp = -69.915, ||grad|| = 50.053]
#     </div>
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:21: FutureWarning: In v4.0, pm.sample will return an `arviz.InferenceData` object instead of a `MultiTrace` by default. You can pass return_inferencedata=True or return_inferencedata=False to be safe and silence this warning.
# Sequential sampling (2 chains in 1 job)
# CompoundStep
# >Metropolis: [y_pred]
# >Metropolis: [mu]
# >Metropolis: [alpha]
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='21000' class='' max='21000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [21000/21000 00:12<00:00 Sampling chain 0, 0 divergences]
#     </div>
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='21000' class='' max='21000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [21000/21000 00:11<00:00 Sampling chain 1, 0 divergences]
#     </div>
# Sampling 2 chains for 1_000 tune and 20_000 draw iterations (2_000 + 40_000 draws total) took 24 seconds.
# The estimated number of effective samples is smaller than 200 for some parameters.
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='15' class='' max='15' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [15/15 00:00<00:00 logp = -20.652, ||grad|| = 0.96448]
#     </div>
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:21: FutureWarning: In v4.0, pm.sample will return an `arviz.InferenceData` object instead of a `MultiTrace` by default. You can pass return_inferencedata=True or return_inferencedata=False to be safe and silence this warning.
# Sequential sampling (2 chains in 1 job)
# CompoundStep
# >Metropolis: [y_pred]
# >Metropolis: [mu]
# >Metropolis: [alpha]
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='21000' class='' max='21000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [21000/21000 00:11<00:00 Sampling chain 0, 0 divergences]
#     </div>
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='21000' class='' max='21000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [21000/21000 00:11<00:00 Sampling chain 1, 0 divergences]
#     </div>
# Sampling 2 chains for 1_000 tune and 20_000 draw iterations (2_000 + 40_000 draws total) took 24 seconds.
# The number of effective samples is smaller than 10% for some parameters.
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='15' class='' max='15' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [15/15 00:00<00:00 logp = -17.787, ||grad|| = 0.1055]
#     </div>
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:21: FutureWarning: In v4.0, pm.sample will return an `arviz.InferenceData` object instead of a `MultiTrace` by default. You can pass return_inferencedata=True or return_inferencedata=False to be safe and silence this warning.
# Sequential sampling (2 chains in 1 job)
# CompoundStep
# >Metropolis: [y_pred]
# >Metropolis: [mu]
# >Metropolis: [alpha]
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='21000' class='' max='21000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [21000/21000 00:10<00:00 Sampling chain 0, 0 divergences]
#     </div>
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='21000' class='' max='21000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [21000/21000 00:10<00:00 Sampling chain 1, 0 divergences]
#     </div>
# Sampling 2 chains for 1_000 tune and 20_000 draw iterations (2_000 + 40_000 draws total) took 21 seconds.
# The estimated number of effective samples is smaller than 200 for some parameters.
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='13' class='' max='13' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [13/13 00:00<00:00 logp = -34.154, ||grad|| = 0.012106]
#     </div>
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:21: FutureWarning: In v4.0, pm.sample will return an `arviz.InferenceData` object instead of a `MultiTrace` by default. You can pass return_inferencedata=True or return_inferencedata=False to be safe and silence this warning.
# Sequential sampling (2 chains in 1 job)
# CompoundStep
# >Metropolis: [y_pred]
# >Metropolis: [mu]
# >Metropolis: [alpha]
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='21000' class='' max='21000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [21000/21000 00:12<00:00 Sampling chain 0, 0 divergences]
#     </div>
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='21000' class='' max='21000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [21000/21000 00:12<00:00 Sampling chain 1, 0 divergences]
#     </div>
# Sampling 2 chains for 1_000 tune and 20_000 draw iterations (2_000 + 40_000 draws total) took 24 seconds.
# The estimated number of effective samples is smaller than 200 for some parameters.
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='15' class='' max='15' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [15/15 00:00<00:00 logp = -17.143, ||grad|| = 0.067026]
#     </div>
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:21: FutureWarning: In v4.0, pm.sample will return an `arviz.InferenceData` object instead of a `MultiTrace` by default. You can pass return_inferencedata=True or return_inferencedata=False to be safe and silence this warning.
# Sequential sampling (2 chains in 1 job)
# CompoundStep
# >Metropolis: [y_pred]
# >Metropolis: [mu]
# >Metropolis: [alpha]
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='21000' class='' max='21000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [21000/21000 00:10<00:00 Sampling chain 0, 0 divergences]
#     </div>
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='21000' class='' max='21000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [21000/21000 00:10<00:00 Sampling chain 1, 0 divergences]
#     </div>
# Sampling 2 chains for 1_000 tune and 20_000 draw iterations (2_000 + 40_000 draws total) took 21 seconds.
# The estimated number of effective samples is smaller than 200 for some parameters.
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='18' class='' max='18' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [18/18 00:00<00:00 logp = -112.83, ||grad|| = 22.193]
#     </div>
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:21: FutureWarning: In v4.0, pm.sample will return an `arviz.InferenceData` object instead of a `MultiTrace` by default. You can pass return_inferencedata=True or return_inferencedata=False to be safe and silence this warning.
# Sequential sampling (2 chains in 1 job)
# CompoundStep
# >Metropolis: [y_pred]
# >Metropolis: [mu]
# >Metropolis: [alpha]
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='21000' class='' max='21000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [21000/21000 00:11<00:00 Sampling chain 0, 0 divergences]
#     </div>
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='21000' class='' max='21000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [21000/21000 00:11<00:00 Sampling chain 1, 0 divergences]
#     </div>
# Sampling 2 chains for 1_000 tune and 20_000 draw iterations (2_000 + 40_000 draws total) took 24 seconds.
# The number of effective samples is smaller than 10% for some parameters.
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='16' class='' max='16' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [16/16 00:00<00:00 logp = -21.702, ||grad|| = 0.48141]
#     </div>
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:21: FutureWarning: In v4.0, pm.sample will return an `arviz.InferenceData` object instead of a `MultiTrace` by default. You can pass return_inferencedata=True or return_inferencedata=False to be safe and silence this warning.
# Sequential sampling (2 chains in 1 job)
# CompoundStep
# >Metropolis: [y_pred]
# >Metropolis: [mu]
# >Metropolis: [alpha]
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='21000' class='' max='21000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [21000/21000 00:11<00:00 Sampling chain 0, 0 divergences]
#     </div>
#     <div>
#         <style>
# ...
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='22' class='' max='22' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [22/22 00:00<00:00 logp = -25.622, ||grad|| = 3.0971e-05]
#     </div>
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:21: FutureWarning: In v4.0, pm.sample will return an `arviz.InferenceData` object instead of a `MultiTrace` by default. You can pass return_inferencedata=True or return_inferencedata=False to be safe and silence this warning.
# Sequential sampling (2 chains in 1 job)
# CompoundStep
# >Metropolis: [y_pred]
# >Metropolis: [mu]
# >Metropolis: [alpha]
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='21000' class='' max='21000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [21000/21000 00:11<00:00 Sampling chain 0, 0 divergences]
#     </div>
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='21000' class='' max='21000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [21000/21000 00:11<00:00 Sampling chain 1, 0 divergences]
#     </div>
# Sampling 2 chains for 1_000 tune and 20_000 draw iterations (2_000 + 40_000 draws total) took 24 seconds.
# The number of effective samples is smaller than 10% for some parameters.
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='16' class='' max='16' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [16/16 00:00<00:00 logp = -288.69, ||grad|| = 16.254]
#     </div>
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:21: FutureWarning: In v4.0, pm.sample will return an `arviz.InferenceData` object instead of a `MultiTrace` by default. You can pass return_inferencedata=True or return_inferencedata=False to be safe and silence this warning.
# Sequential sampling (2 chains in 1 job)
# CompoundStep
# >Metropolis: [y_pred]
# >Metropolis: [mu]
# >Metropolis: [alpha]
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='21000' class='' max='21000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [21000/21000 00:12<00:00 Sampling chain 0, 0 divergences]
#     </div>
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='21000' class='' max='21000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [21000/21000 00:12<00:00 Sampling chain 1, 0 divergences]
#     </div>
# Sampling 2 chains for 1_000 tune and 20_000 draw iterations (2_000 + 40_000 draws total) took 25 seconds.
# The estimated number of effective samples is smaller than 200 for some parameters.
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='16' class='' max='16' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [16/16 00:00<00:00 logp = -25.524, ||grad|| = 1.422]
#     </div>
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:21: FutureWarning: In v4.0, pm.sample will return an `arviz.InferenceData` object instead of a `MultiTrace` by default. You can pass return_inferencedata=True or return_inferencedata=False to be safe and silence this warning.
# Sequential sampling (2 chains in 1 job)
# CompoundStep
# >Metropolis: [y_pred]
# >Metropolis: [mu]
# >Metropolis: [alpha]
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='21000' class='' max='21000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [21000/21000 00:12<00:00 Sampling chain 0, 0 divergences]
#     </div>
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='21000' class='' max='21000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [21000/21000 00:11<00:00 Sampling chain 1, 0 divergences]
#     </div>
# Sampling 2 chains for 1_000 tune and 20_000 draw iterations (2_000 + 40_000 draws total) took 24 seconds.
# The number of effective samples is smaller than 10% for some parameters.
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='15' class='' max='15' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [15/15 00:00<00:00 logp = -84.376, ||grad|| = 4.6484]
#     </div>
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:21: FutureWarning: In v4.0, pm.sample will return an `arviz.InferenceData` object instead of a `MultiTrace` by default. You can pass return_inferencedata=True or return_inferencedata=False to be safe and silence this warning.
# Sequential sampling (2 chains in 1 job)
# CompoundStep
# >Metropolis: [y_pred]
# >Metropolis: [mu]
# >Metropolis: [alpha]
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='21000' class='' max='21000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [21000/21000 00:11<00:00 Sampling chain 0, 0 divergences]
#     </div>
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='21000' class='' max='21000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [21000/21000 00:11<00:00 Sampling chain 1, 0 divergences]
#     </div>
# Sampling 2 chains for 1_000 tune and 20_000 draw iterations (2_000 + 40_000 draws total) took 24 seconds.
# The estimated number of effective samples is smaller than 200 for some parameters.
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='13' class='' max='13' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [13/13 00:00<00:00 logp = -19.795, ||grad|| = 0.0091119]
#     </div>
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:21: FutureWarning: In v4.0, pm.sample will return an `arviz.InferenceData` object instead of a `MultiTrace` by default. You can pass return_inferencedata=True or return_inferencedata=False to be safe and silence this warning.
# Sequential sampling (2 chains in 1 job)
# CompoundStep
# >Metropolis: [y_pred]
# >Metropolis: [mu]
# >Metropolis: [alpha]
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='21000' class='' max='21000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [21000/21000 00:11<00:00 Sampling chain 0, 0 divergences]
#     </div>
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='21000' class='' max='21000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [21000/21000 00:11<00:00 Sampling chain 1, 0 divergences]
#     </div>
# Sampling 2 chains for 1_000 tune and 20_000 draw iterations (2_000 + 40_000 draws total) took 24 seconds.
# The estimated number of effective samples is smaller than 200 for some parameters.
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='14' class='' max='14' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [14/14 00:00<00:00 logp = -49.973, ||grad|| = 0.02433]
#     </div>
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:21: FutureWarning: In v4.0, pm.sample will return an `arviz.InferenceData` object instead of a `MultiTrace` by default. You can pass return_inferencedata=True or return_inferencedata=False to be safe and silence this warning.
# Sequential sampling (2 chains in 1 job)
# CompoundStep
# >Metropolis: [y_pred]
# >Metropolis: [mu]
# >Metropolis: [alpha]
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='21000' class='' max='21000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [21000/21000 00:11<00:00 Sampling chain 0, 0 divergences]
#     </div>
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='6229' class='' max='21000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       29.66% [6229/21000 00:03<00:08 Sampling chain 1, 0 divergences]
#     </div>

# %%
fig, axs = plt.subplots(3,2, figsize=(12, 6))
axs = axs.ravel()
y_left_max = 5
y_right_max = 3000
x_lim = 60
ix = [3,4,6]

for i, j, p in zip([0,1,2], [0,2,4], participants[ix]):
    axs[j].set_title('Observed: %s' % p)
    axs[j].hist(messages[messages['prev_sender']==p]['time_delay_seconds'].values, range=[0, x_lim], bins=x_lim, histtype='stepfilled')
    axs[j].set_ylim([0, y_left_max])

for i, j, p in zip([0,1,2], [1,3,5], participants[ix]):
    axs[j].set_title('Posterior predictive distribution: %s' % p)
    axs[j].hist(indiv_traces[p].get_values('y_pred'), range=[0, x_lim], bins=x_lim, histtype='stepfilled', color=colors[1])
    axs[j].set_ylim([0, y_right_max])

axs[4].set_xlabel('Response time (seconds)')
axs[5].set_xlabel('Response time (seconds)')

plt.tight_layout()

# %%
combined_y_pred = np.concatenate([v.get_values('y_pred') for k, v in indiv_traces.items()])

x_lim = 60
y_pred = trace.get_values('y_pred')

fig = plt.figure(figsize=(12,6))
fig.add_subplot(211)

fig.add_subplot(211)

_ = plt.hist(combined_y_pred, range=[0, x_lim], bins=x_lim, histtype='stepfilled', color=colors[1])   
_ = plt.xlim(1, x_lim)
_ = plt.ylim(0, 40000)
_ = plt.ylabel('Frequency')
_ = plt.title('Posterior predictive distribution')

fig.add_subplot(212)

_ = plt.hist(messages['time_delay_seconds'].values, range=[0, x_lim], bins=x_lim, histtype='stepfilled')
_ = plt.xlim(0, x_lim)
_ = plt.xlabel('Response time in seconds')
_ = plt.ylim(0, 20)
_ = plt.ylabel('Frequency')
_ = plt.title('Distribution of observed data')

plt.tight_layout()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:9: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   if __name__ == '__main__':

# %%
mu = [5,25,50]
sd = [3,7,2]

plt.figure(figsize=(11,3))
_ = plt.title('Gamma distribution')

with pm.Model() as model:
    for i, (j, k) in enumerate(zip(mu, sd)):
        samples = pm.Gamma('gamma_%s' % i, mu=j, sd=k).random(size=10**6)
        plt.hist(samples, bins=100, range=(0,60), color=colors[i], alpha=1)

_ = plt.legend(['$\mu$ = %s, $\sigma$ = %s' % (mu[a], sd[a]) for a in [0,1,2]])

# %%
with pm.Model() as model:
    hyper_alpha_sd = pm.Uniform('hyper_alpha_sd', lower=0, upper=50)
    hyper_alpha_mu = pm.Uniform('hyper_alpha_mu', lower=0, upper=10)
    
    hyper_mu_sd = pm.Uniform('hyper_mu_sd', lower=0, upper=50)
    hyper_mu_mu = pm.Uniform('hyper_mu_mu', lower=0, upper=60)
    
    alpha = pm.Gamma('alpha', mu=hyper_alpha_mu, sd=hyper_alpha_sd, shape=n_participants)
    mu = pm.Gamma('mu', mu=hyper_mu_mu, sd=hyper_mu_sd, shape=n_participants)
    
    y_est = pm.NegativeBinomial('y_est', 
                                mu=mu[participants_idx], 
                                alpha=alpha[participants_idx], 
                                observed=messages['time_delay_seconds'].values)
    
    y_pred = pm.NegativeBinomial('y_pred', 
                                 mu=mu[participants_idx], 
                                 alpha=alpha[participants_idx],
                                 shape=messages['prev_sender'].shape)
    
    start = pm.find_MAP()
    step = pm.Metropolis()
    hierarchical_trace = pm.sample(200000, step, progressbar=True)
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='208' class='' max='208' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [208/208 00:00<00:00 logp = -2,640.5, ||grad|| = 315.59]
#     </div>
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:23: FutureWarning: In v4.0, pm.sample will return an `arviz.InferenceData` object instead of a `MultiTrace` by default. You can pass return_inferencedata=True or return_inferencedata=False to be safe and silence this warning.
# Sequential sampling (2 chains in 1 job)
# CompoundStep
# >Metropolis: [y_pred]
# >Metropolis: [mu]
# >Metropolis: [alpha]
# >Metropolis: [hyper_mu_mu]
# >Metropolis: [hyper_mu_sd]
# >Metropolis: [hyper_alpha_mu]
# >Metropolis: [hyper_alpha_sd]
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='201000' class='' max='201000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [201000/201000 09:23<00:00 Sampling chain 0, 0 divergences]
#     </div>
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='201000' class='' max='201000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [201000/201000 09:20<00:00 Sampling chain 1, 0 divergences]
#     </div>
# Sampling 2 chains for 1_000 tune and 200_000 draw iterations (2_000 + 400_000 draws total) took 1123 seconds.
# The rhat statistic is larger than 1.4 for some parameters. The sampler did not converge.
# The estimated number of effective samples is smaller than 200 for some parameters.

# %%
pm.traceplot(hierarchical_trace[120000:], 
                 var_names=['mu','alpha','hyper_mu_mu',
                           'hyper_mu_sd','hyper_alpha_mu',
                           'hyper_alpha_sd'])
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: DeprecationWarning: The function `traceplot` from PyMC3 is just an alias for `plot_trace` from ArviZ. Please switch to `pymc3.plot_trace` or `arviz.plot_trace`.
#   after removing the cwd from sys.path.
# Got error No model on context stack. trying to find log_likelihood in translation.
# /usr/local/lib/python3.7/dist-packages/arviz/data/io_pymc3_3x.py:102: FutureWarning: Using `from_pymc3` without the model will be deprecated in a future release. Not using the model will return less accurate and less useful results. Make sure you use the model argument or call from_pymc3 within a model context.
#   FutureWarning,
# Got error No model on context stack. trying to find log_likelihood in translation.
# /usr/local/lib/python3.7/dist-packages/arviz/stats/density_utils.py:481: UserWarning: Your data appears to have a single value or no finite values
#   warnings.warn("Your data appears to have a single value or no finite values")
# /usr/local/lib/python3.7/dist-packages/arviz/stats/density_utils.py:481: UserWarning: Your data appears to have a single value or no finite values
#   warnings.warn("Your data appears to have a single value or no finite values")
# /usr/local/lib/python3.7/dist-packages/arviz/stats/density_utils.py:481: UserWarning: Your data appears to have a single value or no finite values
#   warnings.warn("Your data appears to have a single value or no finite values")
# /usr/local/lib/python3.7/dist-packages/arviz/stats/density_utils.py:481: UserWarning: Your data appears to have a single value or no finite values
#   warnings.warn("Your data appears to have a single value or no finite values")
# /usr/local/lib/python3.7/dist-packages/arviz/stats/density_utils.py:481: UserWarning: Your data appears to have a single value or no finite values
#   warnings.warn("Your data appears to have a single value or no finite values")
# /usr/local/lib/python3.7/dist-packages/arviz/stats/density_utils.py:481: UserWarning: Your data appears to have a single value or no finite values
#   warnings.warn("Your data appears to have a single value or no finite values")
# /usr/local/lib/python3.7/dist-packages/arviz/stats/density_utils.py:481: UserWarning: Your data appears to have a single value or no finite values
#   warnings.warn("Your data appears to have a single value or no finite values")
# /usr/local/lib/python3.7/dist-packages/arviz/stats/density_utils.py:481: UserWarning: Your data appears to have a single value or no finite values
#   warnings.warn("Your data appears to have a single value or no finite values")
# /usr/local/lib/python3.7/dist-packages/arviz/stats/density_utils.py:481: UserWarning: Your data appears to have a single value or no finite values
#   warnings.warn("Your data appears to have a single value or no finite values")
# /usr/local/lib/python3.7/dist-packages/arviz/stats/density_utils.py:481: UserWarning: Your data appears to have a single value or no finite values
#   warnings.warn("Your data appears to have a single value or no finite values")
# /usr/local/lib/python3.7/dist-packages/arviz/stats/density_utils.py:481: UserWarning: Your data appears to have a single value or no finite values
#   warnings.warn("Your data appears to have a single value or no finite values")
# /usr/local/lib/python3.7/dist-packages/arviz/stats/density_utils.py:481: UserWarning: Your data appears to have a single value or no finite values
#   warnings.warn("Your data appears to have a single value or no finite values")
# /usr/local/lib/python3.7/dist-packages/arviz/stats/density_utils.py:481: UserWarning: Your data appears to have a single value or no finite values
#   warnings.warn("Your data appears to have a single value or no finite values")
# /usr/local/lib/python3.7/dist-packages/arviz/stats/density_utils.py:481: UserWarning: Your data appears to have a single value or no finite values
#   warnings.warn("Your data appears to have a single value or no finite values")
# /usr/local/lib/python3.7/dist-packages/arviz/stats/density_utils.py:481: UserWarning: Your data appears to have a single value or no finite values
#   warnings.warn("Your data appears to have a single value or no finite values")
# /usr/local/lib/python3.7/dist-packages/arviz/stats/density_utils.py:481: UserWarning: Your data appears to have a single value or no finite values
#   warnings.warn("Your data appears to have a single value or no finite values")
# /usr/local/lib/python3.7/dist-packages/arviz/stats/density_utils.py:481: UserWarning: Your data appears to have a single value or no finite values
#   warnings.warn("Your data appears to have a single value or no finite values")
# /usr/local/lib/python3.7/dist-packages/arviz/stats/density_utils.py:481: UserWarning: Your data appears to have a single value or no finite values
#   warnings.warn("Your data appears to have a single value or no finite values")
# /usr/local/lib/python3.7/dist-packages/arviz/stats/density_utils.py:481: UserWarning: Your data appears to have a single value or no finite values
#   warnings.warn("Your data appears to have a single value or no finite values")
# /usr/local/lib/python3.7/dist-packages/arviz/stats/density_utils.py:481: UserWarning: Your data appears to have a single value or no finite values
#   warnings.warn("Your data appears to have a single value or no finite values")
# /usr/local/lib/python3.7/dist-packages/arviz/stats/density_utils.py:481: UserWarning: Your data appears to have a single value or no finite values
#   warnings.warn("Your data appears to have a single value or no finite values")
# /usr/local/lib/python3.7/dist-packages/arviz/stats/density_utils.py:481: UserWarning: Your data appears to have a single value or no finite values
#   warnings.warn("Your data appears to have a single value or no finite values")
# /usr/local/lib/python3.7/dist-packages/arviz/stats/density_utils.py:481: UserWarning: Your data appears to have a single value or no finite values
#   warnings.warn("Your data appears to have a single value or no finite values")
# /usr/local/lib/python3.7/dist-packages/arviz/stats/density_utils.py:481: UserWarning: Your data appears to have a single value or no finite values
#   warnings.warn("Your data appears to have a single value or no finite values")
# /usr/local/lib/python3.7/dist-packages/arviz/stats/density_utils.py:481: UserWarning: Your data appears to have a single value or no finite values
#   warnings.warn("Your data appears to have a single value or no finite values")
# /usr/local/lib/python3.7/dist-packages/arviz/stats/density_utils.py:481: UserWarning: Your data appears to have a single value or no finite values
#   warnings.warn("Your data appears to have a single value or no finite values")
# /usr/local/lib/python3.7/dist-packages/arviz/stats/density_utils.py:481: UserWarning: Your data appears to have a single value or no finite values
#   warnings.warn("Your data appears to have a single value or no finite values")
# /usr/local/lib/python3.7/dist-packages/arviz/stats/density_utils.py:481: UserWarning: Your data appears to have a single value or no finite values
#   warnings.warn("Your data appears to have a single value or no finite values")
# /usr/local/lib/python3.7/dist-packages/arviz/stats/density_utils.py:481: UserWarning: Your data appears to have a single value or no finite values
#   warnings.warn("Your data appears to have a single value or no finite values")
# /usr/local/lib/python3.7/dist-packages/arviz/stats/density_utils.py:481: UserWarning: Your data appears to have a single value or no finite values
#   warnings.warn("Your data appears to have a single value or no finite values")
# /usr/local/lib/python3.7/dist-packages/arviz/stats/density_utils.py:481: UserWarning: Your data appears to have a single value or no finite values
#   warnings.warn("Your data appears to have a single value or no finite values")
# /usr/local/lib/python3.7/dist-packages/arviz/stats/density_utils.py:481: UserWarning: Your data appears to have a single value or no finite values
#   warnings.warn("Your data appears to have a single value or no finite values")
# /usr/local/lib/python3.7/dist-packages/arviz/stats/density_utils.py:481: UserWarning: Your data appears to have a single value or no finite values
#   warnings.warn("Your data appears to have a single value or no finite values")
# /usr/local/lib/python3.7/dist-packages/arviz/stats/density_utils.py:481: UserWarning: Your data appears to have a single value or no finite values
#   warnings.warn("Your data appears to have a single value or no finite values")
# /usr/local/lib/python3.7/dist-packages/arviz/stats/density_utils.py:481: UserWarning: Your data appears to have a single value or no finite values
#   warnings.warn("Your data appears to have a single value or no finite values")
# /usr/local/lib/python3.7/dist-packages/arviz/stats/density_utils.py:481: UserWarning: Your data appears to have a single value or no finite values
#   warnings.warn("Your data appears to have a single value or no finite values")
# /usr/local/lib/python3.7/dist-packages/arviz/stats/density_utils.py:481: UserWarning: Your data appears to have a single value or no finite values
#   warnings.warn("Your data appears to have a single value or no finite values")
# /usr/local/lib/python3.7/dist-packages/arviz/stats/density_utils.py:481: UserWarning: Your data appears to have a single value or no finite values
#   warnings.warn("Your data appears to have a single value or no finite values")
# /usr/local/lib/python3.7/dist-packages/arviz/stats/density_utils.py:481: UserWarning: Your data appears to have a single value or no finite values
#   warnings.warn("Your data appears to have a single value or no finite values")
# /usr/local/lib/python3.7/dist-packages/arviz/stats/density_utils.py:481: UserWarning: Your data appears to have a single value or no finite values
#   warnings.warn("Your data appears to have a single value or no finite values")
# /usr/local/lib/python3.7/dist-packages/arviz/stats/density_utils.py:481: UserWarning: Your data appears to have a single value or no finite values
#   warnings.warn("Your data appears to have a single value or no finite values")
# /usr/local/lib/python3.7/dist-packages/arviz/stats/density_utils.py:481: UserWarning: Your data appears to have a single value or no finite values
#   warnings.warn("Your data appears to have a single value or no finite values")
# /usr/local/lib/python3.7/dist-packages/arviz/stats/density_utils.py:481: UserWarning: Your data appears to have a single value or no finite values
#   warnings.warn("Your data appears to have a single value or no finite values")
# /usr/local/lib/python3.7/dist-packages/arviz/stats/density_utils.py:481: UserWarning: Your data appears to have a single value or no finite values
#   warnings.warn("Your data appears to have a single value or no finite values")
# /usr/local/lib/python3.7/dist-packages/arviz/stats/density_utils.py:481: UserWarning: Your data appears to have a single value or no finite values
#   warnings.warn("Your data appears to have a single value or no finite values")
# /usr/local/lib/python3.7/dist-packages/arviz/stats/density_utils.py:481: UserWarning: Your data appears to have a single value or no finite values
#   warnings.warn("Your data appears to have a single value or no finite values")
# /usr/local/lib/python3.7/dist-packages/arviz/stats/density_utils.py:481: UserWarning: Your data appears to have a single value or no finite values
#   warnings.warn("Your data appears to have a single value or no finite values")
# /usr/local/lib/python3.7/dist-packages/arviz/stats/density_utils.py:481: UserWarning: Your data appears to have a single value or no finite values
#   warnings.warn("Your data appears to have a single value or no finite values")
# /usr/local/lib/python3.7/dist-packages/arviz/stats/density_utils.py:481: UserWarning: Your data appears to have a single value or no finite values
#   warnings.warn("Your data appears to have a single value or no finite values")
# /usr/local/lib/python3.7/dist-packages/arviz/stats/density_utils.py:481: UserWarning: Your data appears to have a single value or no finite values
#   warnings.warn("Your data appears to have a single value or no finite values")
# /usr/local/lib/python3.7/dist-packages/arviz/stats/density_utils.py:481: UserWarning: Your data appears to have a single value or no finite values
#   warnings.warn("Your data appears to have a single value or no finite values")
# /usr/local/lib/python3.7/dist-packages/arviz/stats/density_utils.py:481: UserWarning: Your data appears to have a single value or no finite values
#   warnings.warn("Your data appears to have a single value or no finite values")
# /usr/local/lib/python3.7/dist-packages/arviz/stats/density_utils.py:481: UserWarning: Your data appears to have a single value or no finite values
#   warnings.warn("Your data appears to have a single value or no finite values")
# /usr/local/lib/python3.7/dist-packages/arviz/stats/density_utils.py:481: UserWarning: Your data appears to have a single value or no finite values
#   warnings.warn("Your data appears to have a single value or no finite values")

# %%
x_lim = 60
y_pred = hierarchical_trace.get_values('y_pred')[::1000].ravel()

fig = plt.figure(figsize=(12,6))
fig.add_subplot(211)

fig.add_subplot(211)

plt.hist(y_pred, range=[0, x_lim], bins=x_lim, histtype='stepfilled', color=colors[1])   
plt.xlim(1, x_lim)
plt.ylabel('Frequency')
plt.title('Posterior predictive distribution')

fig.add_subplot(212)

plt.hist(messages['time_delay_seconds'].values, range=[0, x_lim], bins=x_lim, histtype='stepfilled')
plt.xlabel('Response time in seconds')
plt.ylabel('Frequency')
plt.title('Distribution of observed data')

plt.tight_layout()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:7: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   import sys

# %%
hier_mu = hierarchical_trace['mu'][500:].mean(axis=0)
hier_alpha = hierarchical_trace['alpha'][500:].mean(axis=0)
indv_mu = [indiv_traces[p]['mu'][500:].mean() for p in participants]
indv_alpha = [indiv_traces[p]['alpha'][500:].mean() for p in participants]

fig = plt.figure(figsize=(8, 6))
ax = fig.add_subplot(111, xlabel='mu', ylabel='alpha', 
                     title='Pooled vs. Partially Pooled Negative Binomial Model', 
                     xlim=(5, 45), ylim=(0, 10))

ax.scatter(indv_mu, indv_alpha, c=colors[5], s=50, label = 'Pooled', zorder=3)
ax.scatter(hier_mu, hier_alpha, c=colors[6], s=50, label = 'Partially Pooled', zorder=4)
for i in range(len(indv_mu)):  
    ax.arrow(indv_mu[i], indv_alpha[i], hier_mu[i] - indv_mu[i], hier_alpha[i] - indv_alpha[i], 
            fc="grey", ec="grey", length_includes_head=True, alpha=.5, head_width=0)

ax.legend()

# %%
def participant_y_pred(person):
    """Return posterior predictive for person"""
    ix = np.where(participants == person)[0][0]
    return hierarchical_trace['y_pred'][100000:, ix]
    # return np.where(participants == person)

# %%
print("Here are some samples from Louise Regan's posterior predictive distribution: \n %s" % participant_y_pred('Louise Regan'))
# Out:
# Here are some samples from Louise Regan's posterior predictive distribution:
#  [27 27 27 ... 33 34 35]

# %%
def person_plotA(person_name):
    ix_check = participant_y_pred(person_name) > 10
    plt.hist(participant_y_pred(person_name)[~ix_check], range=[0, x_lim], bins=x_lim, histtype='stepfilled', label='<10 seconds')
    plt.hist(participant_y_pred(person_name)[ix_check], range=[0, x_lim], bins=x_lim, histtype='stepfilled', label='>10 seconds')
    plt.title('Posterior predictive \ndistribution for %s' % person_name)
    plt.xlabel('Response time')
    plt.ylabel('Frequency')
    plt.legend()

def person_plotB(person_name):
    x = np.linspace(1, 60, num=60)
    num_samples = float(len(participant_y_pred(person_name)))
    prob_lt_x = [100*sum(participant_y_pred(person_name) < i)/num_samples for i in x]
    plt.plot(x, prob_lt_x, color=colors[4])
    plt.fill_between(x, prob_lt_x, color=colors[4], alpha=0.3)
    plt.scatter(10, float(100*sum(participant_y_pred(person_name) < 10))/num_samples, s=180, c=colors[4])
    plt.title('Probability of responding \nto %s before time (t)' % person_name)
    plt.xlabel('Response time (t)')
    plt.ylabel('Cumulative probability t')
    plt.ylim(ymin=0, ymax=100)
    plt.xlim(xmin=0, xmax=60)

fig = plt.figure(figsize=(11,6))
fig.add_subplot(221)
person_plotA('Cian O\'Mahony')
fig.add_subplot(222)
person_plotB('Cian O\'Mahony')

fig.add_subplot(223)
person_plotA('Louise Regan')
fig.add_subplot(224)
person_plotB('Louise Regan')

plt.tight_layout()

# %%
def prob_persona_faster(persona, personb):
    return np.float(sum(participant_y_pred(persona) < participant_y_pred(personb)))/len(participant_y_pred(persona))

print("Probability that Cian O'Mahony is responded to faster than Louise Regan: {:.2%}".format(prob_persona_faster('Cian O\'Mahony', 'Louise Regan')))
# Out:
# Probability that Cian O'Mahony is responded to faster than Louise Regan: 39.80%

# %%
# Create an empty dataframe
ab_dist_df = pd.DataFrame(index=participants, columns=participants, dtype=np.float)

# populate each cell in dataframe with persona_less_personb()
for a, b in itertools.permutations(participants, 2):
    ab_dist_df.loc[a, b] = prob_persona_faster(a, b)
    
# populate the diagonal
for a in participants:
    ab_dist_df.loc[a, a] = 0.5

# %%
# Plot heatmap
f, ax = plt.subplots(figsize=(12, 9))
cmap = plt.get_cmap("Spectral")
sns.heatmap(ab_dist_df, square=True, cmap=cmap)
plt.title('Probability that Person A will be responded to faster than Person B')
plt.ylabel('Person A')
plt.xlabel('Person B')
# Out:
# Text(0.5, 63.5, 'Person B')
